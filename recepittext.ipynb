# %%
# Install required libs
# !pip install python-doctr transformers torch torchvision --quiet

from doctr.io import DocumentFile
from doctr.models import ocr_predictor
from transformers import pipeline

# 1️ Load and run OCR on receipt image
ocr_model = ocr_predictor(pretrained=True)
doc = DocumentFile.from_images("/content/5096.png")  # change to your file path
ocr_result = ocr_model(doc)

# Extract plain text from OCR output
text = " ".join([word.value for page in ocr_result.pages for block in page.blocks for line in block.lines for word in line.words])

# 2️ Load NER model (from Hugging Face)
ner = pipeline("ner", model="Jean-Baptiste/camembert-ner-with-dates", aggregation_strategy="simple")

# 3️ Run NER on OCR text
entities = ner(text)

print("OCR Text:", text)
print("NER Entities:", entities)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.4/288.4 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.7 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
# Downloading https://doctr-static.mindee.com/models?id=v0.8.1/fast_base-688a8b34.pt&src=0 to /root/.cache/doctr/models/fast_base-688a8b34.pt
#   0%|          | 0/65814772 [00:00<?, ?it/s]
# Downloading https://doctr-static.mindee.com/models?id=v0.12.0/crnn_vgg16_bn-0417f351.pt&src=0 to /root/.cache/doctr/models/crnn_vgg16_bn-0417f351.pt
#   0%|          | 0/63303144 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/970 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/423 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/811k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# Device set to use cpu
# OCR Text: Waitrose 8 Shell Crown Park Rushden NN10 GAR Site: 2549 Telephone No. 01933 355099 VAT No. 457 280 VAT Rates ABDEF VAT No. 236 763 255 VAT Rate C 51.32 litre Pump # 04 FUELSAVE DIESEL C 67.69 E 1.319 C / litro WR Ess milk semi-skimmed C 0.50 A Total & 68.19 VISA £ 68.19 0.00 % VAT C 0.00 20.00 X VAT E £ 11.28 Total net £ 56.91 2019-04-13 14:14:44 Customer Copy Terminal ID 05254901 ID/STAN/BATCH : 469327/069437/540 Entry Mode Chip/1 Card Name Visa Seq, Number 01 AID A0000000031010 App. crypt. E3B1B38CCA26BD5F XXXXXXXXXXXX1094 Start date 05/18 Expires : **/** SALE AMOUNT 68.19 GBP Response 000 APPROVED Auth Code - 008599 Verification : PIN Please retain for your records No loyalty card presented Register for loyalty today and enjoy member benefits immediately, with rewards on both fuel and shop goods Visit www. shell.co.uk for more information To register ei ther downl oad the Shell app or use the websi ite Get even more from Shell Date Time Num POS CNo Shift 13/04/19 14:14 18989 01 1012 707 Thank You For Shopping At Waitrose & Shell
# NER Entities: [{'entity_group': 'LOC', 'score': np.float32(0.97802466), 'word': 'Waitrose 8 Shell Crown Park Rushden NN10 GAR Site', 'start': 0, 'end': 49}, {'entity_group': 'DATE', 'score': np.float32(0.8608062), 'word': '2019-04-13', 'start': 328, 'end': 339}, {'entity_group': 'MISC', 'score': np.float32(0.65153265), 'word': 'Customer Copy Terminal', 'start': 348, 'end': 371}, {'entity_group': 'MISC', 'score': np.float32(0.59961605), 'word': 'Entry Mode Chi', 'start': 417, 'end': 432}, {'entity_group': 'DATE', 'score': np.float32(0.98004055), 'word': '05/18', 'start': 541, 'end': 547}, {'entity_group': 'DATE', 'score': np.float32(0.58915013), 'word': 'day', 'start': 726, 'end': 729}, {'entity_group': 'MISC', 'score': np.float32(0.95428014), 'word': 'Shell', 'start': 887, 'end': 893}, {'entity_group': 'MISC', 'score': np.float32(0.9086932), 'word': 'Shell Date Time Num POS CNo Shift', 'start': 937, 'end': 971}, {'entity_group': 'DATE', 'score': np.float32(0.98780847), 'word': '13/04/19', 'start': 971, 'end': 980}, {'entity_group': 'MISC', 'score': np.float32(0.7392966), 'word': 'Thank You For Shopping At', 'start': 1004, 'end': 1030}, {'entity_group': 'ORG', 'score': np.float32(0.8137967), 'word': 'Waitrose & Shell', 'start': 1030, 'end': 1047}]
