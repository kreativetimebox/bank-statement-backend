# %%
# !pip install transformers torch pandas pillow
# Out:
# Requirement already satisfied: transformers in j:\anaconda\lib\site-packages (4.52.4)
# Requirement already satisfied: torch in j:\anaconda\lib\site-packages (2.7.0)
# Requirement already satisfied: pandas in j:\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: pillow in j:\anaconda\lib\site-packages (10.4.0)
# Requirement already satisfied: filelock in j:\anaconda\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in j:\anaconda\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in j:\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in j:\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in j:\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in j:\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in j:\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in j:\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in j:\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in j:\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in j:\anaconda\lib\site-packages (from torch) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in j:\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in j:\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in j:\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in j:\anaconda\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in j:\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in j:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in j:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in j:\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in j:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in j:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in j:\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in j:\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in j:\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in j:\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in j:\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in j:\anaconda\lib\site-packages (from requests->transformers) (2025.4.26)

# %%
import json
import torch
import pandas as pd
from PIL import Image
from transformers import LayoutLMv3Processor, LayoutLMv3ForTokenClassification
from typing import List, Dict, Tuple

class DocumentProcessor:
    def __init__(self):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.processor = LayoutLMv3Processor.from_pretrained(
            "microsoft/layoutlmv3-base", 
            apply_ocr=False,
            token=True  # Remove if using public model
        )
        self.model = LayoutLMv3ForTokenClassification.from_pretrained(
            "nielsr/layoutlmv3-finetuned-funsd"  # Public FUNSD-tuned model
        ).to(self.device)
        self.id2label = self.model.config.id2label
        print(f"Initialized processor and model on {self.device}")

    def load_document(self, json_path: str, image_path: str) -> Tuple[List[str], List[List[int]], Image.Image]:
        """Load document data from JSON and image"""
        with open(json_path) as f:
            data = json.load(f)
        
        words = data["words"]
        boxes = data["bboxes"]
        image = Image.open(image_path).convert("RGB")
        
        print(f"Loaded document with {len(words)} words from {json_path}")
        return words, boxes, image

    def preprocess(self, words: List[str], boxes: List[List[int]], image: Image.Image) -> Dict[str, torch.Tensor]:
        """Preprocess document for model input"""
        encoding = self.processor(
            image,
            words,
            boxes=boxes,
            return_tensors="pt",
            truncation=True,
            padding="max_length",
            max_length=512
        ).to(self.device)
        return encoding

    def predict(self, encoding: Dict[str, torch.Tensor]) -> List[int]:
        """Run model inference"""
        with torch.no_grad():
            outputs = self.model(**encoding)
        return outputs.logits.argmax(dim=-1).squeeze().tolist()

    def process_results(
        self, 
        words: List[str], 
        boxes: List[List[int]], 
        predictions: List[int], 
        encoding: Dict[str, torch.Tensor]
    ) -> List[Dict[str, str]]:
        """Process model predictions into structured entities"""
        tokens = self.processor.tokenizer.convert_ids_to_tokens(encoding["input_ids"].squeeze())
        word_ids = encoding.word_ids()
        
        entities = []
        current_entity = {"text": "", "label": "", "bboxes": []}
        
        for idx, (token, word_id) in enumerate(zip(tokens, word_ids)):
            if word_id is None:
                continue
                
            label = self.id2label[predictions[idx]]
            
            # Handle entity boundaries
            if label.startswith("B-"):
                if current_entity["text"]:
                    entities.append(current_entity.copy())
                current_entity = {
                    "text": token.replace("▁", ""),
                    "label": label[2:],
                    "bboxes": [boxes[word_id]]
                }
            elif label.startswith("I-") and current_entity["label"] == label[2:]:
                current_entity["text"] += " " + token.replace("▁", "")
                current_entity["bboxes"].append(boxes[word_id])
            else:
                if current_entity["text"]:
                    entities.append(current_entity.copy())
                current_entity = {"text": "", "label": "", "bboxes": []}
        
        if current_entity["text"]:
            entities.append(current_entity)
            
        return entities

    def merge_bboxes(self, entities: List[Dict]) -> List[Dict]:
        """Calculate merged bounding boxes for multi-word entities"""
        for entity in entities:
            if entity["bboxes"]:
                x0 = min(box[0] for box in entity["bboxes"])
                y0 = min(box[1] for box in entity["bboxes"])
                x1 = max(box[2] for box in entity["bboxes"])
                y1 = max(box[3] for box in entity["bboxes"])
                entity["bbox"] = f"({x0}, {y0}, {x1}, {y1})"
            else:
                entity["bbox"] = "N/A"
            del entity["bboxes"]
        return entities

    def process_document(self, json_path: str, image_path: str) -> pd.DataFrame:
        """Full document processing pipeline"""
        # Load document
        words, boxes, image = self.load_document(json_path, image_path)
        
        # Preprocess
        encoding = self.preprocess(words, boxes, image)
        
        # Predict
        predictions = self.predict(encoding)
        
        # Process results
        entities = self.process_results(words, boxes, predictions, encoding)
        entities = self.merge_bboxes(entities)
        
        # Create DataFrame
        df = pd.DataFrame(entities)[["label", "text", "bbox"]]
        df.columns = ["Entity Type", "Text Content", "Bounding Box"]
        
        print(f"Extracted {len(df)} entities from document")
        return df

    def save_results(self, df: pd.DataFrame, output_path: str = "results.csv"):
        """Save results to CSV"""
        df.to_csv(output_path, index=False)
        print(f"Results saved to {output_path}")

if __name__ == "__main__":
    # Initialize processor
    processor = DocumentProcessor()
    
    # Process document
    json_file = "document.json"
    image_file = r"C:\Users\HP\Desktop\Bank Project\Invoice Images Bank Statement\Arul paul invoice.png"
    result_df = processor.process_document(json_file, image_file)
    
    # Display and save results
    print("\nExtracted Entities:")
    print(result_df)
    processor.save_results(result_df, "document_entities.csv")
# Out:
# ---------------------------------------------------------------------------
# LocalTokenNotFoundError                   Traceback (most recent call last)
# Cell In[5], line 138
#     134         print(f"Results saved to {output_path}")
#     136 if __name__ == "__main__":
#     137     # Initialize processor
# --> 138     processor = DocumentProcessor()
#     140     # Process document
#     141     json_file = "document.json"
#
# Cell In[5], line 11, in DocumentProcessor.__init__(self)
#       9 def __init__(self):
#      10     self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ---> 11     self.processor = LayoutLMv3Processor.from_pretrained(
#      12         "microsoft/layoutlmv3-base",
#      13         apply_ocr=False,
#      14         token=True  # Remove if using public model
#      15     )
#      16     self.model = LayoutLMv3ForTokenClassification.from_pretrained(
#      17         "nielsr/layoutlmv3-finetuned-funsd"  # Public FUNSD-tuned model
#      18     ).to(self.device)
#      19     self.id2label = self.model.config.id2label
#
# File j:\anaconda\Lib\site-packages\transformers\processing_utils.py:1186, in ProcessorMixin.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#    1183     kwargs["token"] = token
#    1185 args = cls._get_arguments_from_pretrained(pretrained_model_name_or_path, **kwargs)
# -> 1186 processor_dict, kwargs = cls.get_processor_dict(pretrained_model_name_or_path, **kwargs)
#    1187 return cls.from_args_and_dict(args, processor_dict, **kwargs)
#
# File j:\anaconda\Lib\site-packages\transformers\processing_utils.py:803, in ProcessorMixin.get_processor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     799 processor_file = PROCESSOR_NAME
#     801 try:
#     802     # Load from local folder or from cache or download from model Hub and cache
# --> 803     resolved_processor_file = cached_file(
#     804         pretrained_model_name_or_path,
#     805         processor_file,
#     806         cache_dir=cache_dir,
#     807         force_download=force_download,
#     808         proxies=proxies,
#     809         resume_download=resume_download,
#     810         local_files_only=local_files_only,
#     811         token=token,
#     812         user_agent=user_agent,
#     813         revision=revision,
#     814         subfolder=subfolder,
#     815         _raise_exceptions_for_missing_entries=False,
#     816     )
#     818     # chat_template.json is a legacy file used by the processor class
#     819     # a raw chat_template.jinja is preferred in future
#     820     resolved_chat_template_file = cached_file(
#     821         pretrained_model_name_or_path,
#     822         LEGACY_PROCESSOR_CHAT_TEMPLATE_FILE,
#    (...)
#     832         _raise_exceptions_for_missing_entries=False,
#     833     )
#
# File j:\anaconda\Lib\site-packages\transformers\utils\hub.py:312, in cached_file(path_or_repo_id, filename, **kwargs)
#     254 def cached_file(
#     255     path_or_repo_id: Union[str, os.PathLike],
#     256     filename: str,
#     257     **kwargs,
#     258 ) -> Optional[str]:
#     259     """
#     260     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     261
#    (...)
#     310     ```
#     311     """
# --> 312     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     313     file = file[0] if file is not None else file
#     314     return file
#
# File j:\anaconda\Lib\site-packages\transformers\utils\hub.py:557, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     554     # Any other Exception type should now be re-raised, in order to provide helpful error messages and break the execution flow
#     555     # (EntryNotFoundError will be treated outside this block and correctly re-raised if needed)
#     556     elif not isinstance(e, EntryNotFoundError):
# --> 557         raise e
#     559 resolved_files = [
#     560     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     561 ]
#     562 # If there are any missing file and the flag is active, raise
#
# File j:\anaconda\Lib\site-packages\transformers\utils\hub.py:470, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     467 try:
#     468     if len(full_filenames) == 1:
#     469         # This is slightly better for only 1 file
# --> 470         hf_hub_download(
#     471             path_or_repo_id,
#     472             filenames[0],
#     473             subfolder=None if len(subfolder) == 0 else subfolder,
#     474             repo_type=repo_type,
#     475             revision=revision,
#     476             cache_dir=cache_dir,
#     477             user_agent=user_agent,
#     478             force_download=force_download,
#     479             proxies=proxies,
#     480             resume_download=resume_download,
#     481             token=token,
#     482             local_files_only=local_files_only,
#     483         )
#     484     else:
#     485         snapshot_download(
#     486             path_or_repo_id,
#     487             allow_patterns=full_filenames,
#    (...)
#     496             local_files_only=local_files_only,
#     497         )
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\file_download.py:972, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     969 if repo_type not in constants.REPO_TYPES:
#     970     raise ValueError(f"Invalid repo type: {repo_type}. Accepted repo types are: {str(constants.REPO_TYPES)}")
# --> 972 hf_headers = build_hf_headers(
#     973     token=token,
#     974     library_name=library_name,
#     975     library_version=library_version,
#     976     user_agent=user_agent,
#     977     headers=headers,
#     978 )
#     980 if local_dir is not None:
#     981     if local_dir_use_symlinks != "auto":
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\utils\_headers.py:126, in build_hf_headers(token, library_name, library_version, user_agent, headers, is_write_action)
#      54 """
#      55 Build headers dictionary to send in a HF Hub call.
#      56
#    (...)
#     123         If `token=True` but token is not saved locally.
#     124 """
#     125 # Get auth token to send
# --> 126 token_to_send = get_token_to_send(token)
#     128 # Combine headers
#     129 hf_headers = {
#     130     "user-agent": _http_user_agent(
#     131         library_name=library_name,
#    (...)
#     134     )
#     135 }
#
# File j:\anaconda\Lib\site-packages\huggingface_hub\utils\_headers.py:159, in get_token_to_send(token)
#     157 if token is True:
#     158     if cached_token is None:
# --> 159         raise LocalTokenNotFoundError(
#     160             "Token is required (`token=True`), but no token found. You"
#     161             " need to provide a token or be logged in to Hugging Face with"
#     162             " `hf auth login` or `huggingface_hub.login`. See"
#     163             " https://huggingface.co/settings/tokens."
#     164         )
#     165     return cached_token
#     167 # Case implicit use of the token is forbidden by env variable
#
# LocalTokenNotFoundError: Token is required (`token=True`), but no token found. You need to provide a token or be logged in to Hugging Face with `hf auth login` or `huggingface_hub.login`. See https://huggingface.co/settings/tokens.

# %%
# !pip install transformers datasets torch torchvision pytesseract Pillow
# Out:
# Requirement already satisfied: transformers in j:\anaconda\lib\site-packages (4.52.4)
# Requirement already satisfied: datasets in j:\anaconda\lib\site-packages (3.6.0)
# Requirement already satisfied: torch in j:\anaconda\lib\site-packages (2.7.0)
# Requirement already satisfied: torchvision in j:\anaconda\lib\site-packages (0.22.0)
# Requirement already satisfied: pytesseract in j:\anaconda\lib\site-packages (0.3.13)
# Requirement already satisfied: Pillow in j:\anaconda\lib\site-packages (10.4.0)
# Requirement already satisfied: filelock in j:\anaconda\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in j:\anaconda\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in j:\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in j:\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in j:\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in j:\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in j:\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in j:\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in j:\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in j:\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in j:\anaconda\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in j:\anaconda\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in j:\anaconda\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in j:\anaconda\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in j:\anaconda\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in j:\anaconda\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in j:\anaconda\lib\site-packages (from torch) (4.14.0)
# Requirement already satisfied: sympy>=1.13.3 in j:\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in j:\anaconda\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in j:\anaconda\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: setuptools in j:\anaconda\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in j:\anaconda\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in j:\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in j:\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in j:\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in j:\anaconda\lib\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in j:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in j:\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in j:\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in j:\anaconda\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in j:\anaconda\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in j:\anaconda\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in j:\anaconda\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.11.0)
# Requirement already satisfied: six>=1.5 in j:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import json
import pytesseract
from PIL import Image
from transformers import LayoutLMv3Processor, LayoutLMv3ForTokenClassification
import torch

# 🔧 Set up paths
image_path = r"C:\Users\HP\Desktop\Bank Project\Invoice Images Bank Statement\Book 201.png"  # Replace with your actual image path
output_json_path = r"C:\Users\HP\Desktop\Bank Project\Json Output\output.json"

# 📷 Load image
image = Image.open(image_path).convert("RGB")

# 🧠 Load processor and model
processor = LayoutLMv3Processor.from_pretrained("microsoft/layoutlmv3-base", apply_ocr=True)
model = LayoutLMv3ForTokenClassification.from_pretrained("microsoft/layoutlmv3-base")

# 🧾 Process image
encoding = processor(image, return_tensors="pt")
with torch.no_grad():
    outputs = model(**encoding)

# 📊 Get predictions
logits = outputs.logits
predicted_class = logits.argmax(-1)

# 📦 Convert to structured JSON
tokens = processor.tokenizer.convert_ids_to_tokens(encoding.input_ids[0])
boxes = encoding.bbox[0].tolist()
labels = predicted_class[0].tolist()

# 🧮 Build JSON structure
results = []
for token, box, label in zip(tokens, boxes, labels):
    if token not in processor.tokenizer.all_special_tokens:
        results.append({
            "text": token,
            "bbox": box,
            "label": model.config.id2label[label]
        })

# 💾 Save to JSON
with open(output_json_path, "w") as f:
    json.dump(results, f, indent=2)

# 📣 Print output in VS Code terminal
print(json.dumps(results, indent=2))
# Out:
# Some weights of LayoutLMv3ForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [
#   {
#     "text": "\u0120Z",
#     "bbox": [
#       178,
#       133,
#       198,
#       149
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120E",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "leg",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "ant",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120IN",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "VO",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "ICE",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       682,
#       170,
#       731,
#       177
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       682,
#       170,
#       731,
#       177
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120#",
#     "bbox": [
#       736,
#       169,
#       749,
#       178
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       736,
#       169,
#       749,
#       178
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u012010",
#     "bbox": [
#       784,
#       170,
#       820,
#       178
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "654",
#     "bbox": [
#       784,
#       170,
#       820,
#       178
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120\u00e2\u0122",
#     "bbox": [
#       118,
#       177,
#       125,
#       183
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u013b",
#     "bbox": [
#       118,
#       177,
#       125,
#       183
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120[",
#     "bbox": [
#       227,
#       167,
#       245,
#       195
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "=",
#     "bbox": [
#       227,
#       167,
#       245,
#       195
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120mM",
#     "bbox": [
#       251,
#       175,
#       285,
#       195
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120b",
#     "bbox": [
#       288,
#       168,
#       308,
#       192
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120r",
#     "bbox": [
#       313,
#       176,
#       347,
#       192
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "d",
#     "bbox": [
#       313,
#       176,
#       347,
#       192
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120C",
#     "bbox": [
#       350,
#       175,
#       368,
#       195
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "c",
#     "bbox": [
#       350,
#       175,
#       368,
#       195
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120e",
#     "bbox": [
#       371,
#       176,
#       391,
#       192
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       664,
#       184,
#       713,
#       192
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       664,
#       184,
#       713,
#       192
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120date",
#     "bbox": [
#       718,
#       184,
#       749,
#       192
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       718,
#       184,
#       749,
#       192
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u012011",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "/",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "27",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "/",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "20",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "24",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Job",
#     "bbox": [
#       722,
#       199,
#       749,
#       210
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       722,
#       199,
#       749,
#       210
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Wedding",
#     "bbox": [
#       782,
#       198,
#       838,
#       210
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120fl",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "or",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "als",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120345",
#     "bbox": [
#       108,
#       268,
#       129,
#       276
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120W",
#     "bbox": [
#       133,
#       268,
#       147,
#       276
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Main",
#     "bbox": [
#       152,
#       268,
#       183,
#       276
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Bill",
#     "bbox": [
#       705,
#       267,
#       729,
#       275
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       733,
#       269,
#       749,
#       275
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       733,
#       269,
#       749,
#       275
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Ha",
#     "bbox": [
#       783,
#       268,
#       822,
#       279
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "iley",
#     "bbox": [
#       783,
#       268,
#       822,
#       279
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Clark",
#     "bbox": [
#       827,
#       268,
#       859,
#       276
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Los",
#     "bbox": [
#       107,
#       283,
#       129,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Angeles",
#     "bbox": [
#       134,
#       282,
#       186,
#       293
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       134,
#       282,
#       186,
#       293
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120CA",
#     "bbox": [
#       191,
#       282,
#       210,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u012014",
#     "bbox": [
#       216,
#       282,
#       250,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "151",
#     "bbox": [
#       216,
#       282,
#       250,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Address",
#     "bbox": [
#       692,
#       281,
#       749,
#       293
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       692,
#       281,
#       749,
#       293
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120123",
#     "bbox": [
#       784,
#       282,
#       804,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Avenue",
#     "bbox": [
#       809,
#       282,
#       856,
#       290
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120A",
#     "bbox": [
#       860,
#       282,
#       874,
#       292
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       860,
#       282,
#       874,
#       292
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120P",
#     "bbox": [
#       107,
#       297,
#       119,
#       305
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       107,
#       297,
#       119,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01209",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "15",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "95",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Bur",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "bank",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120CA",
#     "bbox": [
#       843,
#       296,
#       863,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01205",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "67",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "89",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120F",
#     "bbox": [
#       108,
#       311,
#       119,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       108,
#       311,
#       119,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01209",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "15",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "05",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Phone",
#     "bbox": [
#       703,
#       310,
#       749,
#       323
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       703,
#       310,
#       749,
#       323
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01208",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "05",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "85",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120elegant",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "em",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "@",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "example",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120F",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "ax",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120NA",
#     "bbox": [
#       783,
#       326,
#       805,
#       334
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Item",
#     "bbox": [
#       108,
#       400,
#       139,
#       408
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120#",
#     "bbox": [
#       144,
#       400,
#       153,
#       408
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Description",
#     "bbox": [
#       234,
#       399,
#       313,
#       413
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Q",
#     "bbox": [
#       475,
#       400,
#       500,
#       411
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "ty",
#     "bbox": [
#       475,
#       400,
#       500,
#       411
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Unit",
#     "bbox": [
#       559,
#       400,
#       589,
#       408
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120price",
#     "bbox": [
#       592,
#       400,
#       625,
#       411
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Discount",
#     "bbox": [
#       702,
#       400,
#       763,
#       408
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Price",
#     "bbox": [
#       856,
#       400,
#       890,
#       408
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       662,
#       613,
#       708,
#       621
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       662,
#       613,
#       708,
#       621
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Sub",
#     "bbox": [
#       713,
#       613,
#       763,
#       621
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "total",
#     "bbox": [
#       713,
#       613,
#       763,
#       621
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "4",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "420",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Tax",
#     "bbox": [
#       708,
#       636,
#       731,
#       645
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Rate",
#     "bbox": [
#       736,
#       636,
#       763,
#       645
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01206",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "%",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Sales",
#     "bbox": [
#       706,
#       660,
#       735,
#       668
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Tax",
#     "bbox": [
#       740,
#       660,
#       763,
#       668
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "265",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "20",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "50",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Deposit",
#     "bbox": [
#       655,
#       684,
#       703,
#       695
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Received",
#     "bbox": [
#       708,
#       683,
#       763,
#       692
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120TOTAL",
#     "bbox": [
#       714,
#       707,
#       769,
#       715
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "4",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "370",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120Please",
#     "bbox": [
#       340,
#       771,
#       377,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120make",
#     "bbox": [
#       382,
#       771,
#       414,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120all",
#     "bbox": [
#       418,
#       771,
#       432,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120checks",
#     "bbox": [
#       437,
#       771,
#       476,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120payable",
#     "bbox": [
#       481,
#       771,
#       527,
#       782
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       532,
#       773,
#       543,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120E",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "leg",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "ant",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Em",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Total",
#     "bbox": [
#       232,
#       785,
#       264,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120due",
#     "bbox": [
#       269,
#       784,
#       290,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120in",
#     "bbox": [
#       294,
#       785,
#       306,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u012090",
#     "bbox": [
#       311,
#       785,
#       325,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120days",
#     "bbox": [
#       329,
#       784,
#       358,
#       796
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       329,
#       784,
#       358,
#       796
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120Over",
#     "bbox": [
#       364,
#       784,
#       418,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "due",
#     "bbox": [
#       364,
#       784,
#       418,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120accounts",
#     "bbox": [
#       422,
#       787,
#       475,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120subject",
#     "bbox": [
#       481,
#       784,
#       523,
#       796
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       528,
#       787,
#       540,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120a",
#     "bbox": [
#       544,
#       788,
#       550,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120service",
#     "bbox": [
#       555,
#       785,
#       596,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120charge",
#     "bbox": [
#       601,
#       785,
#       640,
#       796
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120of",
#     "bbox": [
#       645,
#       785,
#       659,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u01201",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "5",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "%",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": "\u0120per",
#     "bbox": [
#       698,
#       787,
#       717,
#       796
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120month",
#     "bbox": [
#       721,
#       785,
#       764,
#       793
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       721,
#       785,
#       764,
#       793
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120elegant",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "em",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "@",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "example",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120|",
#     "bbox": [
#       512,
#       798,
#       513,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "\u0120www",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_0"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "interest",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "ings",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "ite",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_1"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "LABEL_0"
#   }
# ]

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in j:\anaconda\lib\site-packages (4.52.4)
# Collecting transformers
#   Downloading transformers-4.55.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in j:\anaconda\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in j:\anaconda\lib\site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in j:\anaconda\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in j:\anaconda\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in j:\anaconda\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in j:\anaconda\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in j:\anaconda\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in j:\anaconda\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in j:\anaconda\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in j:\anaconda\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in j:\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in j:\anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.0)
# Requirement already satisfied: colorama in j:\anaconda\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in j:\anaconda\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in j:\anaconda\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in j:\anaconda\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in j:\anaconda\lib\site-packages (from requests->transformers) (2025.4.26)
# Downloading transformers-4.55.0-py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.3 MB 3.0 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.3 MB 3.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.3 MB 3.2 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.3 MB 3.5 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.3 MB 3.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.7/11.3 MB 3.4 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.3 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.3 MB 3.4 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.3 MB 3.5 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.3 MB 3.4 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 9.2/11.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.3 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.3 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
# Successfully installed transformers-4.55.0

# %%
import json
import pytesseract
from PIL import Image
from transformers import (
    LayoutLMv3Processor,
    LayoutLMv3ForTokenClassification,
    Trainer,
    TrainingArguments
)
from datasets import Dataset
import torch

# 🔧 Paths
image_path = r"C:\Users\HP\Desktop\Bank Project\Invoice Images Bank Statement\Book 201.png"
output_json_path = r"C:\Users\HP\Desktop\Bank Project\Json Output\output.json"

# 🧠 Label setup
label_list = ["O", "ACCOUNT_NUMBER", "DATE", "AMOUNT"]
id2label = {i: label for i, label in enumerate(label_list)}
label2id = {label: i for i, label in enumerate(label_list)}

from datasets import Dataset

# ✅ Replace ellipsis with actual dummy values
train_data = {
    "input_ids": [[101, 1234, 5678, 102]],  # token IDs
    "attention_mask": [[1, 1, 1, 1]],       # attention mask
    "bbox": [[[0, 0, 50, 50], [60, 0, 100, 50], [110, 0, 160, 50], [0, 0, 0, 0]]],  # bounding boxes
    "labels": [[0, 1, 0, 0]]                # label IDs
}

train_dataset = Dataset.from_dict(train_data)


# 🧠 Load processor and model
processor = LayoutLMv3Processor.from_pretrained("microsoft/layoutlmv3-base", apply_ocr=True)
model = LayoutLMv3ForTokenClassification.from_pretrained(
    "microsoft/layoutlmv3-base",
    num_labels=len(label_list),
    id2label=id2label,
    label2id=label2id
)

# 🏋️ Training setup
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./layoutlmv3-finetuned",
    per_device_train_batch_size=2,
    num_train_epochs=5,
    logging_dir="./logs",
    save_steps=500,
    logging_steps=100,
    save_total_limit=2,
    remove_unused_columns=False
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    tokenizer=processor.tokenizer
)

# 🚀 Train the model
trainer.train()

# 📷 Load image for inference
image = Image.open(image_path).convert("RGB")

# 🔍 Inference
encoding = processor(image, return_tensors="pt")
with torch.no_grad():
    outputs = model(**encoding)

logits = outputs.logits
predicted_class = logits.argmax(-1)

# 📦 Convert to structured JSON
tokens = processor.tokenizer.convert_ids_to_tokens(encoding.input_ids[0])
boxes = encoding.bbox[0].tolist()
labels = predicted_class[0].tolist()

results = []
for token, box, label in zip(tokens, boxes, labels):
    if token not in processor.tokenizer.all_special_tokens:
        results.append({
            "text": token,
            "bbox": box,
            "label": model.config.id2label[label]
        })

# 💾 Save to JSON
with open(output_json_path, "w") as f:
    json.dump(results, f, indent=2)

# 📣 Print output
print(json.dumps(results, indent=2))
# Out:
# Some weights of LayoutLMv3ForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlmv3-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\HP\AppData\Local\Temp\ipykernel_5540\3204638056.py:59: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:15, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# j:\anaconda\Lib\site-packages\transformers\modeling_utils.py:1614: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# [
#   {
#     "text": "\u0120Z",
#     "bbox": [
#       178,
#       133,
#       198,
#       149
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120E",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "O"
#   },
#   {
#     "text": "leg",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "O"
#   },
#   {
#     "text": "ant",
#     "bbox": [
#       228,
#       129,
#       370,
#       159
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120IN",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "O"
#   },
#   {
#     "text": "VO",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "O"
#   },
#   {
#     "text": "ICE",
#     "bbox": [
#       669,
#       121,
#       894,
#       153
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       682,
#       170,
#       731,
#       177
#     ],
#     "label": "O"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       682,
#       170,
#       731,
#       177
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120#",
#     "bbox": [
#       736,
#       169,
#       749,
#       178
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       736,
#       169,
#       749,
#       178
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u012010",
#     "bbox": [
#       784,
#       170,
#       820,
#       178
#     ],
#     "label": "O"
#   },
#   {
#     "text": "654",
#     "bbox": [
#       784,
#       170,
#       820,
#       178
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120\u00e2\u0122",
#     "bbox": [
#       118,
#       177,
#       125,
#       183
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u013b",
#     "bbox": [
#       118,
#       177,
#       125,
#       183
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120[",
#     "bbox": [
#       227,
#       167,
#       245,
#       195
#     ],
#     "label": "O"
#   },
#   {
#     "text": "=",
#     "bbox": [
#       227,
#       167,
#       245,
#       195
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120mM",
#     "bbox": [
#       251,
#       175,
#       285,
#       195
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120b",
#     "bbox": [
#       288,
#       168,
#       308,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120r",
#     "bbox": [
#       313,
#       176,
#       347,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "d",
#     "bbox": [
#       313,
#       176,
#       347,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120C",
#     "bbox": [
#       350,
#       175,
#       368,
#       195
#     ],
#     "label": "O"
#   },
#   {
#     "text": "c",
#     "bbox": [
#       350,
#       175,
#       368,
#       195
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120e",
#     "bbox": [
#       371,
#       176,
#       391,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       664,
#       184,
#       713,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       664,
#       184,
#       713,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120date",
#     "bbox": [
#       718,
#       184,
#       749,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       718,
#       184,
#       749,
#       192
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u012011",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "/",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "27",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "/",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "20",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "24",
#     "bbox": [
#       784,
#       183,
#       858,
#       194
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Job",
#     "bbox": [
#       722,
#       199,
#       749,
#       210
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       722,
#       199,
#       749,
#       210
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Wedding",
#     "bbox": [
#       782,
#       198,
#       838,
#       210
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120fl",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "O"
#   },
#   {
#     "text": "or",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "O"
#   },
#   {
#     "text": "als",
#     "bbox": [
#       843,
#       199,
#       880,
#       207
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120345",
#     "bbox": [
#       108,
#       268,
#       129,
#       276
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120W",
#     "bbox": [
#       133,
#       268,
#       147,
#       276
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Main",
#     "bbox": [
#       152,
#       268,
#       183,
#       276
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Bill",
#     "bbox": [
#       705,
#       267,
#       729,
#       275
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       733,
#       269,
#       749,
#       275
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       733,
#       269,
#       749,
#       275
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Ha",
#     "bbox": [
#       783,
#       268,
#       822,
#       279
#     ],
#     "label": "O"
#   },
#   {
#     "text": "iley",
#     "bbox": [
#       783,
#       268,
#       822,
#       279
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Clark",
#     "bbox": [
#       827,
#       268,
#       859,
#       276
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Los",
#     "bbox": [
#       107,
#       283,
#       129,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Angeles",
#     "bbox": [
#       134,
#       282,
#       186,
#       293
#     ],
#     "label": "O"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       134,
#       282,
#       186,
#       293
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120CA",
#     "bbox": [
#       191,
#       282,
#       210,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u012014",
#     "bbox": [
#       216,
#       282,
#       250,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "151",
#     "bbox": [
#       216,
#       282,
#       250,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Address",
#     "bbox": [
#       692,
#       281,
#       749,
#       293
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       692,
#       281,
#       749,
#       293
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120123",
#     "bbox": [
#       784,
#       282,
#       804,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Avenue",
#     "bbox": [
#       809,
#       282,
#       856,
#       290
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120A",
#     "bbox": [
#       860,
#       282,
#       874,
#       292
#     ],
#     "label": "O"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       860,
#       282,
#       874,
#       292
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120P",
#     "bbox": [
#       107,
#       297,
#       119,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       107,
#       297,
#       119,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01209",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "15",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "95",
#     "bbox": [
#       124,
#       297,
#       207,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Bur",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "O"
#   },
#   {
#     "text": "bank",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "O"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       783,
#       296,
#       838,
#       306
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120CA",
#     "bbox": [
#       843,
#       296,
#       863,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01205",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "67",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "89",
#     "bbox": [
#       868,
#       296,
#       904,
#       305
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120F",
#     "bbox": [
#       108,
#       311,
#       119,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       108,
#       311,
#       119,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01209",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "15",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "05",
#     "bbox": [
#       124,
#       311,
#       207,
#       320
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Phone",
#     "bbox": [
#       703,
#       310,
#       749,
#       323
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       703,
#       310,
#       749,
#       323
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01208",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "05",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "555",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "-",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "01",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "85",
#     "bbox": [
#       783,
#       311,
#       866,
#       319
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120elegant",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "em",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "@",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "O"
#   },
#   {
#     "text": "example",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "O"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       108,
#       324,
#       298,
#       338
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120F",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "O"
#   },
#   {
#     "text": "ax",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "O"
#   },
#   {
#     "text": ":",
#     "bbox": [
#       721,
#       326,
#       749,
#       333
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120NA",
#     "bbox": [
#       783,
#       326,
#       805,
#       334
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Item",
#     "bbox": [
#       108,
#       400,
#       139,
#       408
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120#",
#     "bbox": [
#       144,
#       400,
#       153,
#       408
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Description",
#     "bbox": [
#       234,
#       399,
#       313,
#       413
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "\u0120Q",
#     "bbox": [
#       475,
#       400,
#       500,
#       411
#     ],
#     "label": "O"
#   },
#   {
#     "text": "ty",
#     "bbox": [
#       475,
#       400,
#       500,
#       411
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Unit",
#     "bbox": [
#       559,
#       400,
#       589,
#       408
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120price",
#     "bbox": [
#       592,
#       400,
#       625,
#       411
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Discount",
#     "bbox": [
#       702,
#       400,
#       763,
#       408
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Price",
#     "bbox": [
#       856,
#       400,
#       890,
#       408
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Inv",
#     "bbox": [
#       662,
#       613,
#       708,
#       621
#     ],
#     "label": "O"
#   },
#   {
#     "text": "oice",
#     "bbox": [
#       662,
#       613,
#       708,
#       621
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Sub",
#     "bbox": [
#       713,
#       613,
#       763,
#       621
#     ],
#     "label": "O"
#   },
#   {
#     "text": "total",
#     "bbox": [
#       713,
#       613,
#       763,
#       621
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": "4",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": "420",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       832,
#       613,
#       890,
#       623
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Tax",
#     "bbox": [
#       708,
#       636,
#       731,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Rate",
#     "bbox": [
#       736,
#       636,
#       763,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01206",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": "%",
#     "bbox": [
#       852,
#       636,
#       890,
#       645
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Sales",
#     "bbox": [
#       706,
#       660,
#       735,
#       668
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Tax",
#     "bbox": [
#       740,
#       660,
#       763,
#       668
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "O"
#   },
#   {
#     "text": "265",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "O"
#   },
#   {
#     "text": "20",
#     "bbox": [
#       843,
#       660,
#       890,
#       670
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "O"
#   },
#   {
#     "text": "50",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "O"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       850,
#       684,
#       890,
#       693
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Deposit",
#     "bbox": [
#       655,
#       684,
#       703,
#       695
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Received",
#     "bbox": [
#       708,
#       683,
#       763,
#       692
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120TOTAL",
#     "bbox": [
#       714,
#       707,
#       769,
#       715
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120$",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": "4",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": ",",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": "370",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": "00",
#     "bbox": [
#       832,
#       707,
#       890,
#       717
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Please",
#     "bbox": [
#       340,
#       771,
#       377,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120make",
#     "bbox": [
#       382,
#       771,
#       414,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120all",
#     "bbox": [
#       418,
#       771,
#       432,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120checks",
#     "bbox": [
#       437,
#       771,
#       476,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120payable",
#     "bbox": [
#       481,
#       771,
#       527,
#       782
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       532,
#       773,
#       543,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120E",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "O"
#   },
#   {
#     "text": "leg",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "ant",
#     "bbox": [
#       548,
#       771,
#       595,
#       782
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "\u0120Em",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       599,
#       771,
#       657,
#       779
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Total",
#     "bbox": [
#       232,
#       785,
#       264,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120due",
#     "bbox": [
#       269,
#       784,
#       290,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120in",
#     "bbox": [
#       294,
#       785,
#       306,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u012090",
#     "bbox": [
#       311,
#       785,
#       325,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120days",
#     "bbox": [
#       329,
#       784,
#       358,
#       796
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       329,
#       784,
#       358,
#       796
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120Over",
#     "bbox": [
#       364,
#       784,
#       418,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "due",
#     "bbox": [
#       364,
#       784,
#       418,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120accounts",
#     "bbox": [
#       422,
#       787,
#       475,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120subject",
#     "bbox": [
#       481,
#       784,
#       523,
#       796
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120to",
#     "bbox": [
#       528,
#       787,
#       540,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120a",
#     "bbox": [
#       544,
#       788,
#       550,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120service",
#     "bbox": [
#       555,
#       785,
#       596,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120charge",
#     "bbox": [
#       601,
#       785,
#       640,
#       796
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120of",
#     "bbox": [
#       645,
#       785,
#       659,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u01201",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "5",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "%",
#     "bbox": [
#       663,
#       785,
#       693,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120per",
#     "bbox": [
#       698,
#       787,
#       717,
#       796
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120month",
#     "bbox": [
#       721,
#       785,
#       764,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       721,
#       785,
#       764,
#       793
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120elegant",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "em",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "brace",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "@",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "example",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       314,
#       798,
#       505,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120|",
#     "bbox": [
#       512,
#       798,
#       513,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": "\u0120www",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "interest",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": "ings",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   },
#   {
#     "text": "ite",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": ".",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "O"
#   },
#   {
#     "text": "com",
#     "bbox": [
#       521,
#       799,
#       671,
#       810
#     ],
#     "label": "ACCOUNT_NUMBER"
#   }
# ]
